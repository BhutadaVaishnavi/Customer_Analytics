# %%
import numpy as np
import pandas as pd
import os
import matplotlib.pyplot as plt
import seaborn as sns
cd = pd.read_csv(r"C:\Users\sagar\OneDrive\Desktop\vaishu\Dataset\Customer_Data.csv")
cd
# Out:
#      User_ID  Gender  Age   Location Device_Type  Product_Browsing_Time  \
# 0          1  Female   23  Ahmedabad      Mobile                     60
# 1          2    Male   25    Kolkata      Tablet                     30
# 2          3    Male   32  Bangalore     Desktop                     37
# 3          4    Male   35      Delhi      Mobile                      7
# 4          5    Male   27  Bangalore      Tablet                     35
# ..       ...     ...  ...        ...         ...                    ...
# 495      496    Male   24     Mumbai      Tablet                     40
# 496      497  Female   24  Hyderabad     Desktop                      8
# 497      498    Male   19       Pune     Desktop                     33
# 498      499    Male   28    Chennai     Desktop                      6
# 499      500  Female   31    Kolkata      Mobile                     16
#
#      Total_Pages_Viewed  Items_Added_to_Cart  Total_Purchases
# ...

# %% [markdown]
# # 1. Gender vs Age

# %%
sns.barplot(data=cd,x="Gender",y="Age")
# Out:
# <AxesSubplot:xlabel='Gender', ylabel='Age'>

# %% [markdown]
# # Gender count

# %%
cd["Gender"].value_counts()
# Out:
# Male      261
# Female    239
# Name: Gender, dtype: int64

# %% [markdown]
# # 2. Gender vs location

# %%
gender_counts=cd.groupby(["Location","Gender"]).size().reset_index(name='count')
gender_counts
# Out:
#      Location  Gender  count
# 0   Ahmedabad  Female     30
# 1   Ahmedabad    Male     32
# 2   Bangalore  Female     27
# 3   Bangalore    Male     34
# 4     Chennai  Female     31
# 5     Chennai    Male     25
# 6       Delhi  Female     34
# 7       Delhi    Male     36
# 8   Hyderabad  Female     30
# 9   Hyderabad    Male     32
# 10    Kolkata  Female     39
# 11    Kolkata    Male     32
# 12     Mumbai  Female     25
# 13     Mumbai    Male     34
# 14       Pune  Female     23
# 15       Pune    Male     36

# %%
sns.barplot(data=gender_counts,x="Location",y="count",hue=gender_counts["Gender"])
plt.title("Gender count by location")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# # 3. Gender vs Device Type

# %%
device_counts=cd.groupby(["Device_Type","Gender"]).size().reset_index(name='count')
device_counts
# Out:
#   Device_Type  Gender  count
# 0     Desktop  Female     82
# 1     Desktop    Male     77
# 2      Mobile  Female     83
# 3      Mobile    Male     95
# 4      Tablet  Female     74
# 5      Tablet    Male     89

# %%
sns.barplot(data=device_counts,x="Device_Type",y="count",hue=device_counts["Gender"])
plt.title("Gender count by Device Type")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
#  # 4. Who is browsing the items for more time?

# %%
sns.barplot(data=cd,x="Gender",y="Product_Browsing_Time")
# Out:
# <AxesSubplot:xlabel='Gender', ylabel='Product_Browsing_Time'>

# %% [markdown]
# # 5. Who viewed most pages

# %%
sns.barplot(data=cd,x="Gender",y="Total_Pages_Viewed")
# Out:
# <AxesSubplot:xlabel='Gender', ylabel='Total_Pages_Viewed'>

# %% [markdown]
# # 6. Who added more items in the cart

# %%
sns.barplot(data=cd,x="Gender",y="Items_Added_to_Cart")
# Out:
# <AxesSubplot:xlabel='Gender', ylabel='Items_Added_to_Cart'>

# %% [markdown]
# # 7.who purchases most items?

# %%
sns.barplot(data=cd,x="Gender",y="Total_Purchases")
# Out:
# <AxesSubplot:xlabel='Gender', ylabel='Total_Purchases'>

# %% [markdown]
# # 8. Age vs Location

# %%
sns.barplot(data=cd,x="Location",y="Age",hue=cd["Gender"])
# Out:
# <AxesSubplot:xlabel='Location', ylabel='Age'>

# %% [markdown]
# # 9. Age vs Device_Type

# %%
sns.barplot(data=cd,x="Device_Type",y="Age")
# Out:
# <AxesSubplot:xlabel='Device_Type', ylabel='Age'>

# %% [markdown]
# # 10.Which age group of people spend more time for browsing?

# %%
sns.barplot(data=cd,y="Product_Browsing_Time",x="Age")
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Product_Browsing_Time'>

# %% [markdown]
# # 11.Which age of people viewed more pages?

# %%
sns.histplot(data = cd['Age'], kde = True,bins=6)
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Count'>

# %% [markdown]
# # 12.1. Age of people and their added item count

# %%
added_item=cd.groupby(["Age","Items_Added_to_Cart"]).size().reset_index(name='count')
added_item
# Out:
#      Age  Items_Added_to_Cart  count
# 0     18                    1      3
# 1     18                    2      6
# 2     18                    3      2
# 3     18                    4      4
# 4     18                    5      1
# ..   ...                  ...    ...
# 179   35                    6      3
# 180   35                    7      2
# 181   35                    8      5
# 182   35                    9      2
# 183   35                   10      4
#
# [184 rows x 3 columns]

# %% [markdown]
# # 12.2. Age vs total cart Value count

# %%
a=added_item.groupby(["Age"])['count'].sum()
a
# Out:
# Age
# 18    29
# 19    26
# 20    24
# 21    36
# 22    30
# 23    32
# 24    25
# 25    27
# 26    27
# 27    32
# 28    28
# 29    35
# 30    23
# 31    26
# 32    28
# 33    20
# 34    22
# 35    30
# Name: count, dtype: int64

# %%
a.plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='Age'>

# %% [markdown]
# # 13. Item purchases count by Age

# %%
p=cd.groupby(["Age","Total_Purchases"]).size().reset_index(name='count')

# %%
p
# Out:
#      Age  Total_Purchases  count
# 0     18                0      4
# 1     18                1      4
# 2     18                2      5
# 3     18                3      3
# 4     18                4      5
# ..   ...              ...    ...
# 103   35                1      6
# 104   35                2      6
# 105   35                3      5
# 106   35                4      1
# 107   35                5      6
#
# [108 rows x 3 columns]

# %%
total_purchases = p.groupby(["Total_Purchases"])['count'].sum()
total_purchases
# Out:
# Total_Purchases
# 0    99
# 1    65
# 2    89
# 3    83
# 4    80
# 5    84
# Name: count, dtype: int64

# %%
total_purchases.plot(kind='bar',)
# Out:
# <AxesSubplot:xlabel='Total_Purchases'>

# %%
total_p= p.groupby(["Total_Purchases","Age"])['count'].sum()
total_p
# Out:
# Total_Purchases  Age
# 0                18     4
#                  19     6
#                  20     3
#                  21     6
#                  22     6
#                        ..
# 5                31     4
#                  32     3
#                  33     6
#                  34     4
#                  35     6
# Name: count, Length: 108, dtype: int64

# %% [markdown]
# # 14.1. device_type count by location

# %%
device_counts=cd.groupby(["Location","Device_Type"]).size().reset_index(name='count')
device_counts
# Out:
#      Location Device_Type  count
# 0   Ahmedabad     Desktop     19
# 1   Ahmedabad      Mobile     22
# 2   Ahmedabad      Tablet     21
# 3   Bangalore     Desktop     26
# 4   Bangalore      Mobile     22
# 5   Bangalore      Tablet     13
# 6     Chennai     Desktop     22
# 7     Chennai      Mobile     18
# 8     Chennai      Tablet     16
# 9       Delhi     Desktop     14
# 10      Delhi      Mobile     30
# 11      Delhi      Tablet     26
# 12  Hyderabad     Desktop     19
# 13  Hyderabad      Mobile     27
# 14  Hyderabad      Tablet     16
# 15    Kolkata     Desktop     19
# 16    Kolkata      Mobile     21
# 17    Kolkata      Tablet     31
# 18     Mumbai     Desktop     19
# 19     Mumbai      Mobile     19
# 20     Mumbai      Tablet     21
# 21       Pune     Desktop     21
# 22       Pune      Mobile     19
# 23       Pune      Tablet     19

# %% [markdown]
# # 14.2. Most Popular device type by location

# %%
sns.barplot(data=device_counts,x="Location",y="count",hue=device_counts["Device_Type"])
plt.title("Most Popular device type by location")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# # 15.1. Showing item browsing time by location

# %%
sns.barplot(data=cd,x="Location",y="Product_Browsing_Time")
# Out:
# <AxesSubplot:xlabel='Location', ylabel='Product_Browsing_Time'>

# %% [markdown]
# # 15.2. Find added item in cart by location

# %%
sns.barplot(data=cd,y="Items_Added_to_Cart",x="Location")
# Out:
# <AxesSubplot:xlabel='Location', ylabel='Items_Added_to_Cart'>

# %% [markdown]
# # 16. From which location's people purchases the most?

# %%
sns.barplot(data=cd,y="Total_Purchases",x="Location")
# Out:
# <AxesSubplot:xlabel='Location', ylabel='Total_Purchases'>

# %% [markdown]
# # 17. Find out the Ratio of browsing time w.r.t total purchases by location

# %%
L= cd.groupby(["Location"])["Product_Browsing_Time","Total_Purchases"].sum().reset_index().sort_values(by='Product_Browsing_Time')
L
# Out:
# C:\Users\sagar\AppData\Local\Temp\ipykernel_23764\4078831725.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   L= cd.groupby(["Location"])["Product_Browsing_Time","Total_Purchases"].sum().reset_index().sort_values(by='Product_Browsing_Time')
#     Location  Product_Browsing_Time  Total_Purchases
# 2    Chennai                   1520              143
# 7       Pune                   1731              126
# 6     Mumbai                   1795              145
# 0  Ahmedabad                   1843              152
# 1  Bangalore                   1985              147
# 3      Delhi                   2056              191
# 4  Hyderabad                   2066              138
# 5    Kolkata                   2374              190

# %%
L["Ratio"] = L["Total_Purchases"] / L["Product_Browsing_Time"]
L = L.sort_values('Ratio')
L
# Out:
#     Location  Product_Browsing_Time  Total_Purchases     Ratio
# 4  Hyderabad                   2066              138  0.066796
# 7       Pune                   1731              126  0.072790
# 1  Bangalore                   1985              147  0.074055
# 5    Kolkata                   2374              190  0.080034
# 6     Mumbai                   1795              145  0.080780
# 0  Ahmedabad                   1843              152  0.082474
# 3      Delhi                   2056              191  0.092899
# 2    Chennai                   1520              143  0.094079

# %%
sns.barplot(data=L,x="Location",y="Ratio")
# Out:
# <AxesSubplot:xlabel='Location', ylabel='Ratio'>

# %% [markdown]
# # 18. Which device was mostly used for browsing

# %%
sns.barplot(data=cd,x="Device_Type",y="Product_Browsing_Time")
# Out:
# <AxesSubplot:xlabel='Device_Type', ylabel='Product_Browsing_Time'>

# %%
sns.barplot(data=cd,x="Device_Type",y="Product_Browsing_Time",hue=cd["Gender"])
# Out:
# <AxesSubplot:xlabel='Device_Type', ylabel='Product_Browsing_Time'>

# %% [markdown]
# # 19.  Find out the Ratio of browsing time w.r.t total purchases by Device_Type

# %%
D_t= cd.groupby(["Device_Type"])["Product_Browsing_Time","Total_Purchases"].sum().reset_index().sort_values(by='Product_Browsing_Time')
D_t
# Out:
# C:\Users\sagar\AppData\Local\Temp\ipykernel_23764\3112779695.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   D_t= cd.groupby(["Device_Type"])["Product_Browsing_Time","Total_Purchases"].sum().reset_index().sort_values(by='Product_Browsing_Time')
#   Device_Type  Product_Browsing_Time  Total_Purchases
# 0     Desktop                   4743              381
# 2      Tablet                   5168              400
# 1      Mobile                   5459              451

# %%
D_t["Ratio"] = D_t["Total_Purchases"] / D_t["Product_Browsing_Time"]
D_t= D_t.sort_values('Ratio')
D_t
# Out:
#   Device_Type  Product_Browsing_Time  Total_Purchases     Ratio
# 2      Tablet                   5168              400  0.077399
# 0     Desktop                   4743              381  0.080329
# 1      Mobile                   5459              451  0.082616

# %%
sns.barplot(data=D_t,x="Device_Type",y="Ratio")
# Out:
# <AxesSubplot:xlabel='Device_Type', ylabel='Ratio'>

# %%
sns.heatmap(cd.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %%
#END
